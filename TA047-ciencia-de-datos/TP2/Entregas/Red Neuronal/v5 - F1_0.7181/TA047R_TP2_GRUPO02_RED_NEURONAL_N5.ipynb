# %% [markdown]
# # Trabajo Práctico 2 - Grupo 02
#
# ### Modelo BETO — Entrega N5
#
# Integrantes:
#
# *   Bermudez, Agustin
# *   Calderón, Tiago
# *   Gonzalez Pautaso, Mateo
# *   Moreyra, Santiago
# *   Nieves, Maylen

# %% [markdown]
# **Dataset:** Train original con max_length=192
#
# **Hiperparámetros:** `lr=2e-05` | `epochs=3` | `max_length=192`
#
# **Justificación:** max_length=192 captura el p99 de longitud (122 tokens) con margen. Verifica si las reseñas largas aportan señal extra.

# %% [markdown]
# ## 1. Instalación de dependencias

# %%
# Deep learning y transformers
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124
# !pip install transformers datasets accelerate

# NLP y preprocesamiento
# !pip install spacy
# !python -m spacy download es_core_news_sm

# ML clásico
# !pip install scikit-learn xgboost joblib

# Data
# !pip install pandas numpy scipy

# Visualización
# !pip install matplotlib seaborn

# Análisis de sentimiento (SentiWordNet)
# !pip install nltk
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu124
# Requirement already satisfied: torch in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (0.21.0+cu124)
# Requirement already satisfied: torchaudio in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (2.6.0+cu124)
# Requirement already satisfied: filelock in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from torch) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: networkx in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from torch) (2026.2.0)
# Requirement already satisfied: setuptools in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from torch) (70.2.0)
# Requirement already satisfied: sympy==1.13.1 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from torchvision) (2.4.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from torchvision) (12.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: transformers in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (5.9.0)
# Requirement already satisfied: datasets in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (4.8.5)
# Requirement already satisfied: accelerate in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (1.13.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from transformers) (1.17.0)
# Requirement already satisfied: numpy>=1.17 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from transformers) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from transformers) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from transformers) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from transformers) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from transformers) (4.67.3)
# Requirement already satisfied: click>=8.4.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.13.0)
# Requirement already satisfied: certifi in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.18)
# Requirement already satisfied: h11>=0.16 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from typer->transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: pyarrow>=21.0.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from datasets) (24.0.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from datasets) (0.4.1)
# Requirement already satisfied: pandas in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from datasets) (3.0.3)
# Requirement already satisfied: requests>=2.32.2 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from datasets) (2.34.2)
# Requirement already satisfied: xxhash in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from datasets) (3.7.0)
# Requirement already satisfied: multiprocess<0.70.20 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from datasets) (0.70.19)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.14.0)
# Requirement already satisfied: psutil in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from accelerate) (7.2.2)
# Requirement already satisfied: torch>=2.0.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from accelerate) (2.6.0+cu124)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.24.2)
# Requirement already satisfied: colorama in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from click>=8.4.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from requests>=2.32.2->datasets) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from requests>=2.32.2->datasets) (2.7.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from rich>=13.8.0->typer->transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from rich>=13.8.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)
# Requirement already satisfied: networkx in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from torch>=2.0.0->accelerate) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: setuptools in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from torch>=2.0.0->accelerate) (70.2.0)
# Requirement already satisfied: sympy==1.13.1 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from pandas->datasets) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: spacy in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (3.8.14)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from spacy) (0.25.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from spacy) (2.4.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from spacy) (2.34.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from spacy) (2.13.4)
# Requirement already satisfied: jinja2 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from spacy) (70.2.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from spacy) (26.2)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.5.20)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: colorama in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.2.1 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.4.1)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.24.0)
# Requirement already satisfied: smart-open>=5.2.1 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.6.1)
# Requirement already satisfied: httpx>=0.24.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: anyio in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.13.0)
# Requirement already satisfied: httpcore==1.* in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from jinja2->spacy) (3.0.3)
# Collecting es-core-news-sm==3.8.0
#   Downloading es_core_news_sm-3.8.0-py3-none-any.whl (12.9 MB)
#      ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#      ---------- ----------------------------- 3.4/12.9 MB 40.3 MB/s eta 0:00:01
#      ---------------------------------------- 12.9/12.9 MB 53.9 MB/s  0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# Requirement already satisfied: scikit-learn in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (1.9.0)
# Requirement already satisfied: xgboost in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (3.2.0)
# Requirement already satisfied: joblib in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (1.5.3)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from scikit-learn) (2.4.4)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from scikit-learn) (2.22.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: pandas in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (2.4.4)
# Requirement already satisfied: scipy in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (1.17.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: matplotlib in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (3.10.9)
# Requirement already satisfied: seaborn in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: tzdata in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: nltk in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (3.9.4)
# Requirement already satisfied: click in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from nltk) (8.4.1)
# Requirement already satisfied: joblib in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from nltk) (2026.5.9)
# Requirement already satisfied: tqdm in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in C:\Users\Valen\Downloads\cdd\.venv312\Lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
nltk.download("sentiwordnet")
nltk.download("wordnet")
nltk.download("omw-1.4")
# Out:
# [nltk_data] Downloading package sentiwordnet to
# [nltk_data]     C:\Users\Valen\AppData\Roaming\nltk_data...
# [nltk_data]   Package sentiwordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Valen\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Valen\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %% [markdown]
# ## 2. Imports y configuración

# %%
import sys
sys.path.insert(0, "../../..")  # TP2/

import numpy as np
import pandas as pd
import torch
from pathlib import Path
from torch.utils.data import Dataset
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    TrainingArguments,
    Trainer,
    EarlyStoppingCallback,
)
from sklearn.metrics import f1_score, classification_report, confusion_matrix

from common.data_utils import get_split, SEED
from common.preprocessing import clean_minimal
from common.evaluation import evaluate

np.random.seed(SEED)
torch.manual_seed(SEED)

DEVICE      = torch.device("cuda" if torch.cuda.is_available() else "cpu")
MODEL_NAME  = "dccuchile/bert-base-spanish-wwm-cased"
MAX_LENGTH  = 192
BATCH_SIZE  = 32
NUM_EPOCHS  = 3
LR          = 2e-05
CLASS_NAMES = ["negativa", "neutra", "positiva"]

print(f"Device: {DEVICE}")
print(f"GPU: {torch.cuda.get_device_name(0)}")
print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
# Out:
# Device: cuda
# GPU: NVIDIA GeForce RTX 3060
# VRAM: 12.9 GB

# %% [markdown]
# ## 3. Carga de datos

# %%
train_df = pd.read_csv("../../../data/train.csv")
test_df  = pd.read_csv("../../../data/test.csv")

print(f"Train: {len(train_df):,} filas")
print(f"Distribucion:\n{train_df['label'].value_counts().sort_index()}")

X_train_raw, X_val_raw, y_train, y_val = get_split(train_df)

print("\nAplicando clean_minimal...")
X_train = np.array([clean_minimal(t) for t in X_train_raw])
X_val   = np.array([clean_minimal(t) for t in X_val_raw])
X_test  = np.array([clean_minimal(t) for t in test_df["text"].values])
print(f"Train: {len(X_train):,} | Val: {len(X_val):,} | Test: {len(X_test):,}")
# Out:
# Train: 51,000 filas
# Distribucion:
# label
# 0    20400
# 1    10200
# 2    20400
# Name: count, dtype: int64
#
# Aplicando clean_minimal...
# Train: 40,800 | Val: 10,200 | Test: 8,500

# %% [markdown]
# ## 4. Dataset y tokenización

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

class ResenasDataset(Dataset):
    def __init__(self, texts, labels=None, tokenizer=None, max_length=128):
        self.encodings = tokenizer(
            list(texts),
            truncation=True,
            padding="max_length",
            max_length=max_length,
            return_tensors="pt",
        )
        self.labels = labels

    def __len__(self):
        return len(self.encodings["input_ids"])

    def __getitem__(self, idx):
        item = {k: v[idx] for k, v in self.encodings.items()}
        if self.labels is not None:
            item["labels"] = torch.tensor(self.labels[idx], dtype=torch.long)
        return item

print("Tokenizando...")
train_dataset = ResenasDataset(X_train, y_train, tokenizer, MAX_LENGTH)
val_dataset   = ResenasDataset(X_val,   y_val,   tokenizer, MAX_LENGTH)
test_dataset  = ResenasDataset(X_test,  None,    tokenizer, MAX_LENGTH)
print("Listo.")
# Out:
# Tokenizando...
# Listo.

# %% [markdown]
# ## 5. Modelo y métricas

# %%
model = AutoModelForSequenceClassification.from_pretrained(
    MODEL_NAME,
    num_labels=3,
    ignore_mismatched_sizes=True,
)
model = model.to(DEVICE)

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=1)
    f1_per = f1_score(labels, preds, average=None, zero_division=0)
    return {
        "f1_macro": f1_score(labels, preds, average="macro", zero_division=0),
        "f1_neg": float(f1_per[0]),
        "f1_neu": float(f1_per[1]),
        "f1_pos": float(f1_per[2]),
    }
# Out:
# Loading weights: 100%|██████████| 197/197 [00:00<00:00, 49203.71it/s]
# [transformers] BertForSequenceClassification LOAD REPORT from: dccuchile/bert-base-spanish-wwm-cased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.predictions.decoder.bias               | UNEXPECTED |
# cls.predictions.decoder.weight             | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# bert.pooler.dense.weight                   | MISSING    |
# classifier.bias                            | MISSING    |
# classifier.weight                          | MISSING    |
# bert.pooler.dense.bias                     | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.

# %% [markdown]
# ## 6. Fine-tuning

# %%
OUTPUT_DIR = Path("models/red_neuronal_beto_v5_original_maxlen192")

training_args = TrainingArguments(
    output_dir=str(OUTPUT_DIR),
    num_train_epochs=NUM_EPOCHS,
    per_device_train_batch_size=BATCH_SIZE,
    per_device_eval_batch_size=BATCH_SIZE,
    learning_rate=LR,
    warmup_ratio=0.1,
    weight_decay=0.01,
    fp16=True,
    eval_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    metric_for_best_model="f1_macro",
    greater_is_better=True,
    logging_steps=100,
    save_total_limit=2,
    report_to="none",
    seed=SEED,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    compute_metrics=compute_metrics,
    callbacks=[EarlyStoppingCallback(early_stopping_patience=2)],
)

print(f"Iniciando fine-tuning: lr={LR} | epochs={NUM_EPOCHS} | max_length={MAX_LENGTH}")
trainer.train()
# Out:
# [transformers] warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
# Iniciando fine-tuning: lr=2e-05 | epochs=3 | max_length=192
#     <div>
#
#       <progress value='3825' max='3825' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3825/3825 19:19, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1 Macro</th>
#       <th>F1 Neg</th>
#       <th>F1 Neu</th>
#       <th>F1 Pos</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.560472</td>
#       <td>0.556131</td>
#       <td>0.688555</td>
#       <td>0.830244</td>
#       <td>0.374804</td>
#       <td>0.860616</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.455458</td>
#       <td>0.554485</td>
#       <td>0.706471</td>
#       <td>0.832321</td>
#       <td>0.418605</td>
#       <td>0.868488</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.387865</td>
#       <td>0.601636</td>
#       <td>0.718138</td>
#       <td>0.823701</td>
#       <td>0.466717</td>
#       <td>0.863996</td>
#     </tr>
#   </tbody>
# </table><p>
# Writing model shards: 100%|██████████| 1/1 [00:01<00:00,  1.67s/it]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.75it/s]
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.85it/s]
# TrainOutput(global_step=3825, training_loss=0.5013517015743879, metrics={'train_runtime': 1159.1173, 'train_samples_per_second': 105.598, 'train_steps_per_second': 3.3, 'total_flos': 1.20769058737152e+16, 'train_loss': 0.5013517015743879, 'epoch': 3.0})

# %% [markdown]
# ## 7. Evaluación en validación

# %%
preds_output = trainer.predict(val_dataset)
y_pred = np.argmax(preds_output.predictions, axis=1)

evaluate("red_neuronal_beto_v5_original_maxlen192", y_val, y_pred,
         hyperparams={
             "model": MODEL_NAME,
             "epochs": NUM_EPOCHS,
             "lr": LR,
             "max_length": MAX_LENGTH,
             "batch_size": BATCH_SIZE,
             "dataset": "original_maxlen192",
         })
# Out:
# === red_neuronal_beto_v5_original_maxlen192 ===
# Hiperparámetros: {'model': 'dccuchile/bert-base-spanish-wwm-cased', 'epochs': 3, 'lr': 2e-05, 'max_length': 192, 'batch_size': 32, 'dataset': 'original_maxlen192'}
#
# F1-macro:  0.7181
# Precision: 0.7190
# Recall:    0.7176
# Accuracy:  0.7708
#
#               precision    recall  f1-score   support
#
#     negativa     0.8162    0.8314    0.8237      4080
#       neutra     0.4825    0.4520    0.4667      2040
#     positiva     0.8585    0.8696    0.8640      4080
#
#     accuracy                         0.7708     10200
#    macro avg     0.7190    0.7176    0.7181     10200
# weighted avg     0.7663    0.7708    0.7684     10200
#
# Matriz de confusión (filas=real, cols=predicho):
#           negativa  neutra  positiva
# negativa      3392     583       105
# neutra         638     922       480
# positiva       126     406      3548

# %%
# Curva de entrenamiento
import matplotlib.pyplot as plt

history  = trainer.state.log_history
eval_f1  = [(x["epoch"], x["eval_f1_macro"]) for x in history if "eval_f1_macro" in x]
eval_neu = [(x["epoch"], x["eval_f1_neu"])   for x in history if "eval_f1_neu"   in x]

fig, ax = plt.subplots(figsize=(8, 4))
if eval_f1:
    epochs, f1s = zip(*eval_f1)
    ax.plot(epochs, f1s, marker="o", label="F1-macro", color="#2ca02c")
    for e, f in zip(epochs, f1s):
        ax.annotate(f"{f:.4f}", (e, f), textcoords="offset points", xytext=(0, 8))
if eval_neu:
    epochs, f1s = zip(*eval_neu)
    ax.plot(epochs, f1s, marker="s", label="F1-neutra", color="#7f7f7f", linestyle="--")
ax.set_xlabel("Epoch"); ax.set_ylabel("F1")
ax.set_title("F1-macro y F1-neutra por época")
ax.legend(); plt.tight_layout(); plt.show()

# %% [markdown]
# ## 8. Guardado del modelo

# %%
SAVE_DIR = Path("models/red_neuronal_beto_v5_original_maxlen192_final")
trainer.save_model(str(SAVE_DIR))
tokenizer.save_pretrained(str(SAVE_DIR))
print(f"Modelo guardado en {SAVE_DIR}")
# Out:
# Writing model shards: 100%|██████████| 1/1 [00:00<00:00,  1.21it/s]
# Modelo guardado en models\red_neuronal_beto_v5_original_maxlen192_final

# %% [markdown]
# ## 9. Submission a Kaggle

# %%
Path("submissions").mkdir(exist_ok=True)
preds_test  = trainer.predict(test_dataset)
y_test_pred = np.argmax(preds_test.predictions, axis=1)

sub = pd.DataFrame({"id": test_df["id"].values, "label": y_test_pred.astype(int)})
sub.to_csv("submissions/submission_red_neuronal_beto_v5_original_maxlen192.csv", index=False)

dist = sub["label"].value_counts(normalize=True).sort_index()
print(f"Guardado: submissions/submission_red_neuronal_beto_v5_original_maxlen192.csv  ({len(sub)} predicciones)")
print(f"Distribucion: {', '.join(f'clase {k}: {v:.1%}' for k, v in dist.items())}")
# Out:
# Guardado: submissions/submission_red_neuronal_beto_v5_original_maxlen192.csv  (8500 predicciones)
# Distribucion: clase 0: 40.8%, clase 1: 19.0%, clase 2: 40.2%
