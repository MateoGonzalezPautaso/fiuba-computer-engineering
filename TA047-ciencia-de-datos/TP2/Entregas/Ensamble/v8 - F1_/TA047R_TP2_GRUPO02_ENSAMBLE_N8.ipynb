# %% [markdown]
# # Trabajo Práctico 2 - Grupo 02
#
# ### Ensamble
#
# Integrantes:
#
# *   Bermudez, Agustin
# *   Calderón, Tiago
# *   Gonzalez Pautaso, Mateo
# *   Moreyra, Santiago
# *   Nieves, Maylen

# %%
# Deep learning y transformers
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124
# !pip install transformers datasets accelerate

# NLP y preprocesamiento
# !pip install spacy
# !python -m spacy download es_core_news_sm

# ML clásico
# !pip install scikit-learn xgboost joblib

# Data
# !pip install pandas numpy scipy

# Visualización
# !pip install matplotlib seaborn

# Análisis de sentimiento (SentiWordNet)
# !pip install nltk
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu124
# Requirement already satisfied: torch in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (0.21.0+cu124)
# Requirement already satisfied: torchaudio in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (2.6.0+cu124)
# Requirement already satisfied: filelock in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch) (3.29.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch) (4.15.0)
# Requirement already satisfied: networkx in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch) (2026.4.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch) (3.2.0)
# Requirement already satisfied: setuptools in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch) (81.0.0)
# Requirement already satisfied: sympy==1.13.1 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torchvision) (2.4.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torchvision) (12.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: transformers in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (5.12.0)
# Requirement already satisfied: datasets in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (5.0.0)
# Requirement already satisfied: accelerate in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (1.14.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from transformers) (1.19.0)
# Requirement already satisfied: numpy>=1.17 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from transformers) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from transformers) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from transformers) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from transformers) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from transformers) (0.8.0)
# Requirement already satisfied: tqdm>=4.60 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from transformers) (4.68.2)
# Requirement already satisfied: filelock in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from datasets) (3.29.4)
# Requirement already satisfied: pyarrow>=21.0.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from datasets) (24.0.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from datasets) (0.4.1)
# Requirement already satisfied: pandas in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from datasets) (3.0.3)
# Requirement already satisfied: requests>=2.32.2 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from datasets) (2.34.2)
# Requirement already satisfied: httpx<1.0.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: xxhash in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from datasets) (3.7.0)
# Requirement already satisfied: multiprocess<0.70.20 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from datasets) (0.70.19)
# Requirement already satisfied: fsspec<=2026.4.0,>=2023.1.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (2026.4.0)
# Requirement already satisfied: psutil in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from accelerate) (7.2.2)
# Requirement already satisfied: torch>=2.0.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from accelerate) (2.6.0+cu124)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (3.14.1)
# Requirement already satisfied: anyio in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (4.13.0)
# Requirement already satisfied: certifi in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (3.18)
# Requirement already satisfied: h11>=0.16 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: click>=8.4.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (8.4.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.5.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (2.7.0)
# Requirement already satisfied: networkx in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (3.6.1)
# Requirement already satisfied: jinja2 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (3.2.0)
# Requirement already satisfied: setuptools in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (81.0.0)
# Requirement already satisfied: sympy==1.13.1 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from typer->transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.4.0,>=2023.1.0->datasets) (1.24.2)
# Requirement already satisfied: six>=1.5 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from rich>=13.8.0->typer->transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from rich>=13.8.0->typer->transformers) (2.20.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.3)
# Requirement already satisfied: mdurl~=0.1 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)
# Requirement already satisfied: spacy in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (3.8.14)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from spacy) (0.25.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from spacy) (4.68.2)
# Requirement already satisfied: numpy>=1.19.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from spacy) (2.4.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from spacy) (2.34.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from spacy) (2.13.4)
# Requirement already satisfied: jinja2 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from spacy) (81.0.0)
# Requirement already satisfied: packaging>=20.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from spacy) (26.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.5.20)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: click>=8.2.1 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.4.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.24.0)
# Requirement already satisfied: smart-open>=5.2.1 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.6.1)
# Requirement already satisfied: httpx>=0.24.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from jinja2->spacy) (3.0.3)
# Requirement already satisfied: anyio in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (2.20.0)
# Requirement already satisfied: wrapt in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.2.1)
# Requirement already satisfied: mdurl~=0.1 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Collecting es-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.8.0/es_core_news_sm-3.8.0-py3-none-any.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 5.2 MB/s eta 0:00:0000:0100:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# Requirement already satisfied: scikit-learn in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (1.9.0)
# Requirement already satisfied: xgboost in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (3.2.0)
# Requirement already satisfied: joblib in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (1.5.3)
# Requirement already satisfied: numpy>=1.24.1 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from scikit-learn) (2.4.6)
# Requirement already satisfied: scipy>=1.10.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: narwhals>=2.0.1 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from scikit-learn) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: nvidia-nccl-cu12 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from xgboost) (2.21.5)
# Requirement already satisfied: pandas in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (3.0.3)
# Requirement already satisfied: numpy in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (2.4.6)
# Requirement already satisfied: scipy in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (1.17.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: matplotlib in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (3.11.0)
# Requirement already satisfied: seaborn in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: six>=1.5 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: nltk in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (3.9.4)
# Requirement already satisfied: click in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from nltk) (8.4.1)
# Requirement already satisfied: joblib in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from nltk) (2026.5.9)
# Requirement already satisfied: tqdm in /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages (from nltk) (4.68.2)

# %%
import sys
sys.path.insert(0, "../../..")  # TP2/

# ============================================================
# MODIFICAR PARA CADA ENTREGA
# ============================================================

NOMBRE_ENTREGA = "ensamble_2red_1xgb_1rf_1nb_llm_v8_2"  # nombre del archivo de submission

# Modelos transformer - lista de carpetas con el modelo guardado
BASE = "/home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/models"

TRANSFORMER_DIRS = [
    f"{BASE}/red_neuronal_xlm_roberta_n13_large",
    f"{BASE}/red_neuronal_roberta_bne_n1_original_51k_final",

]

# Modelos sklearn (joblib) - lista de paths a archivos .joblib
# Dejar vacío [] si el ensamble es solo de transformers
SKLEARN_PATHS = [
    f"{BASE}/xgb_bow_aug_baseline_v6_3/xgb_bow_aug_baseline_v6_3.joblib",
    f"{BASE}/rf_tfidf_randomsearch_v4/rf_tfidf_randomsearch_v4.joblib",
    f"{BASE}/nb_bow_gridsearch/nb_bow_gridsearch.joblib"
]

# Pesos por modelo - deben sumar 1.0 y tener el mismo orden
# que TRANSFORMER_DIRS + SKLEARN_PATHS
PESOS = [
    0.31,
    0.30,
    0.13,
    0.13,
    0.13
]

assert len(PESOS) == len(TRANSFORMER_DIRS) + len(SKLEARN_PATHS), \
    "La cantidad de pesos debe ser igual a la cantidad total de modelos"
assert abs(sum(PESOS) - 1.0) < 1e-6, "Los pesos deben sumar 1.0"

print(f"Entrega: {NOMBRE_ENTREGA}")
print(f"Modelos transformer: {len(TRANSFORMER_DIRS)}")
print(f"Modelos sklearn:     {len(SKLEARN_PATHS)}")
print(f"Pesos: {PESOS}")
# Out:
# Entrega: ensamble_2red_1xgb_1rf_1nb_llm_v8_2
# Modelos transformer: 2
# Modelos sklearn:     3
# Pesos: [0.31, 0.3, 0.13, 0.13, 0.13]

# %% [markdown]
# ## 1. Imports

# %%
import numpy as np
import pandas as pd
import torch
import joblib
from pathlib import Path
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from sklearn.metrics import f1_score

from common.data_utils import get_split, make_bow, SEED
from common.preprocessing import clean_minimal, clean_classical
from common.evaluation import evaluate
from common.io_utils import make_submission

DEVICE     = torch.device("cuda" if torch.cuda.is_available() else "cpu")
MAX_LENGTH = 128
BATCH_SIZE = 64

print(f"Device: {DEVICE}")
np.random.seed(SEED)
# Out:
# Device: cpu

# %% [markdown]
# ## 2. Carga de datos

# %%
train_df = pd.read_csv("../../../data/train_augmented_llm_balanced.csv")
test_df  = pd.read_csv("../../../data/test.csv")

X_train_raw, X_val_raw, y_train, y_val = get_split(train_df)

# Para transformers: clean_minimal
X_val_minimal  = np.array([clean_minimal(t) for t in X_val_raw])
X_test_minimal = np.array([clean_minimal(t) for t in test_df["text"].values])

# Para modelos sklearn: clean_classical (solo si hay SKLEARN_PATHS)
if SKLEARN_PATHS:
    print("Preprocesando para sklearn...")
    X_val_classical  = np.array([clean_classical(t) for t in X_val_raw])
    X_test_classical = np.array([clean_classical(t) for t in test_df["text"].values])
    print("Listo.")

print(f"Val: {len(X_val_minimal):,} | Test: {len(X_test_minimal):,}")
# Out:
# Preprocesando para sklearn...
# Listo.
# Val: 13,311 | Test: 8,500

# %% [markdown]
# ## 3. Funciones de inferencia

# %%
class TextDataset(Dataset):
    def __init__(self, texts, tokenizer, max_length):
        self.encodings = tokenizer(
            list(texts), truncation=True, padding="max_length",
            max_length=max_length, return_tensors="pt",
        )
    def __len__(self): return len(self.encodings["input_ids"])
    def __getitem__(self, idx): return {k: v[idx] for k, v in self.encodings.items()}


def get_transformer_probs(model_dir: str, texts: np.ndarray) -> np.ndarray:
    """Devuelve matriz (n, 3) de probabilidades softmax para un transformer guardado."""
    print(f"  Cargando {model_dir}...")
    tokenizer = AutoTokenizer.from_pretrained(model_dir)
    model     = AutoModelForSequenceClassification.from_pretrained(model_dir)
    model     = model.to(DEVICE)
    model.eval()

    dataset    = TextDataset(texts, tokenizer, MAX_LENGTH)
    dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=False)

    all_probs = []
    with torch.no_grad():
        for batch in dataloader:
            batch  = {k: v.to(DEVICE) for k, v in batch.items()}
            logits = model(**batch).logits
            probs  = torch.softmax(logits, dim=-1).cpu().numpy()
            all_probs.append(probs)

    # Liberar VRAM antes de cargar el siguiente modelo
    del model
    torch.cuda.empty_cache()

    return np.vstack(all_probs)


def get_sklearn_probs(model_path: str, texts: np.ndarray) -> np.ndarray:
    """Devuelve matriz (n, 3) de probabilidades para un modelo sklearn."""
    print(f"  Cargando {model_path}...")
    model = joblib.load(model_path)
    return model.predict_proba(texts)


print("Funciones cargadas.")
# Out:
# Funciones cargadas.

# %% [markdown]
# ## 4. Inferencia de cada modelo

# %%
import os
for d in TRANSFORMER_DIRS:
    print(d, "→", os.path.exists(d))
# Out:
# /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/models/red_neuronal_xlm_roberta_n13_large → True
# /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/models/red_neuronal_roberta_bne_n1_original_51k_final → True

# %%
val_probs_list  = []
test_probs_list = []

# Transformers
for model_dir in TRANSFORMER_DIRS:
    print(f"\nTransformer: {model_dir}")
    val_probs_list.append(get_transformer_probs(model_dir, X_val_minimal))
    test_probs_list.append(get_transformer_probs(model_dir, X_test_minimal))

# Modelos sklearn
for i, model_path in enumerate(SKLEARN_PATHS):
    print(f"\nSklearn: {model_path}")
    val_probs_list.append(get_sklearn_probs(model_path, X_val_classical))
    test_probs_list.append(get_sklearn_probs(model_path, X_test_classical))

print(f"\nProbabilidades obtenidas de {len(val_probs_list)} modelos.")
# Out:
# Transformer: /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/models/red_neuronal_xlm_roberta_n13_large
#   Cargando /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/models/red_neuronal_xlm_roberta_n13_large...
# Loading weights:   0%|          | 0/393 [00:00<?, ?it/s]
#   Cargando /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/models/red_neuronal_xlm_roberta_n13_large...
# Loading weights:   0%|          | 0/393 [00:00<?, ?it/s]
# Transformer: /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/models/red_neuronal_roberta_bne_n1_original_51k_final
#   Cargando /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/models/red_neuronal_roberta_bne_n1_original_51k_final...
# Loading weights:   0%|          | 0/393 [00:00<?, ?it/s]
#   Cargando /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/models/red_neuronal_roberta_bne_n1_original_51k_final...
# Loading weights:   0%|          | 0/393 [00:00<?, ?it/s]
# Sklearn: /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/models/xgb_bow_aug_baseline_v6_3/xgb_bow_aug_baseline_v6_3.joblib
#   Cargando /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/models/xgb_bow_aug_baseline_v6_3/xgb_bow_aug_baseline_v6_3.joblib...
#   Cargando /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/models/xgb_bow_aug_baseline_v6_3/xgb_bow_aug_baseline_v6_3.joblib...
#
# Sklearn: /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/models/rf_tfidf_randomsearch_v4/rf_tfidf_randomsearch_v4.joblib
#   Cargando /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/models/rf_tfidf_randomsearch_v4/rf_tfidf_randomsearch_v4.joblib...
# /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages/sklearn/base.py:525: InconsistentVersionWarning: Trying to unpickle estimator TfidfTransformer from version 1.6.1 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages/sklearn/base.py:525: InconsistentVersionWarning: Trying to unpickle estimator TfidfVectorizer from version 1.6.1 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages/sklearn/base.py:525: InconsistentVersionWarning: Trying to unpickle estimator DecisionTreeClassifier from version 1.6.1 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages/sklearn/base.py:525: InconsistentVersionWarning: Trying to unpickle estimator RandomForestClassifier from version 1.6.1 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages/sklearn/base.py:525: InconsistentVersionWarning: Trying to unpickle estimator Pipeline from version 1.6.1 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
#   Cargando /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/models/rf_tfidf_randomsearch_v4/rf_tfidf_randomsearch_v4.joblib...
# /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages/sklearn/base.py:525: InconsistentVersionWarning: Trying to unpickle estimator TfidfTransformer from version 1.6.1 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages/sklearn/base.py:525: InconsistentVersionWarning: Trying to unpickle estimator TfidfVectorizer from version 1.6.1 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages/sklearn/base.py:525: InconsistentVersionWarning: Trying to unpickle estimator DecisionTreeClassifier from version 1.6.1 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages/sklearn/base.py:525: InconsistentVersionWarning: Trying to unpickle estimator RandomForestClassifier from version 1.6.1 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages/sklearn/base.py:525: InconsistentVersionWarning: Trying to unpickle estimator Pipeline from version 1.6.1 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Sklearn: /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/models/nb_bow_gridsearch/nb_bow_gridsearch.joblib
#   Cargando /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/models/nb_bow_gridsearch/nb_bow_gridsearch.joblib...
# /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages/sklearn/base.py:525: InconsistentVersionWarning: Trying to unpickle estimator CountVectorizer from version 1.6.1 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages/sklearn/base.py:525: InconsistentVersionWarning: Trying to unpickle estimator MultinomialNB from version 1.6.1 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/.venv/lib/python3.12/site-packages/sklearn/base.py:525: InconsistentVersionWarning: Trying to unpickle estimator Pipeline from version 1.6.1 when using version 1.9.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
#   Cargando /home/mateo-gonzalez-pautaso/Desktop/TA047R-1C2026-GRUPO02/TP2/models/nb_bow_gridsearch/nb_bow_gridsearch.joblib...
#
# Probabilidades obtenidas de 5 modelos.

# %% [markdown]
# ## 5. Ensamble por soft voting ponderado

# %%
# Promedio ponderado de probabilidades
val_probs_ensemble  = sum(w * p for w, p in zip(PESOS, val_probs_list))
test_probs_ensemble = sum(w * p for w, p in zip(PESOS, test_probs_list))

# Predicción final: clase con mayor probabilidad
y_pred_val  = np.argmax(val_probs_ensemble,  axis=1)
y_pred_test = np.argmax(test_probs_ensemble, axis=1)

# Evaluación en validación
evaluate(NOMBRE_ENTREGA, y_val, y_pred_val,
         hyperparams={
             "modelos": [Path(d).name for d in TRANSFORMER_DIRS] +
                        [Path(p).stem for p in SKLEARN_PATHS],
             "pesos": PESOS,
         })
# Out:
# === ensamble_2red_1xgb_1rf_1nb_llm_v8_2 ===
# Hiperparámetros: {'modelos': ['red_neuronal_xlm_roberta_n13_large', 'red_neuronal_roberta_bne_n1_original_51k_final', 'xgb_bow_aug_baseline_v6_3', 'rf_tfidf_randomsearch_v4', 'nb_bow_gridsearch'], 'pesos': [0.31, 0.3, 0.13, 0.13, 0.13]}
#
# F1-macro:  0.8393
# Precision: 0.8390
# Recall:    0.8397
# Accuracy:  0.8403
#
#               precision    recall  f1-score   support
#
#     negativa     0.8570    0.8718    0.8643      4469
#       neutra     0.7811    0.7581    0.7694      4373
#     positiva     0.8790    0.8892    0.8841      4469
#
#     accuracy                         0.8403     13311
#    macro avg     0.8390    0.8397    0.8393     13311
# weighted avg     0.8395    0.8403    0.8398     13311
#
# Matriz de confusión (filas=real, cols=predicho):
#           negativa  neutra  positiva
# negativa      3896     537        36
# neutra         547    3315       511
# positiva       103     392      3974

# %% [markdown]
# ## 6. Comparación contra modelos individuales

# %%
print("F1-macro por modelo individual vs ensamble:")
print(f"  Ensamble: {f1_score(y_val, y_pred_val, average='macro'):.4f}")
for i, (probs, peso) in enumerate(zip(val_probs_list, PESOS)):
    preds_i = np.argmax(probs, axis=1)
    f1_i    = f1_score(y_val, preds_i, average="macro")
    nombre  = (TRANSFORMER_DIRS + SKLEARN_PATHS)[i]
    print(f"  Modelo {i+1} (peso={peso}): {f1_i:.4f} — {Path(nombre).name}")
# Out:
# F1-macro por modelo individual vs ensamble:
#   Ensamble: 0.8393
#   Modelo 1 (peso=0.31): 0.2131 — red_neuronal_xlm_roberta_n13_large
#   Modelo 2 (peso=0.3): 0.8253 — red_neuronal_roberta_bne_n1_original_51k_final
#   Modelo 3 (peso=0.13): 0.8436 — xgb_bow_aug_baseline_v6_3.joblib
#   Modelo 4 (peso=0.13): 0.8086 — rf_tfidf_randomsearch_v4.joblib
#   Modelo 5 (peso=0.13): 0.7412 — nb_bow_gridsearch.joblib

# %% [markdown]
# ## 7. Submission

# %%
Path("submissions").mkdir(exist_ok=True)

sub = pd.DataFrame({"id": test_df["id"].values, "label": y_pred_test.astype(int)})
sub.to_csv(f"submissions/submission_{NOMBRE_ENTREGA}.csv", index=False)

dist = sub["label"].value_counts(normalize=True).sort_index()
print(f"Guardado: submissions/submission_{NOMBRE_ENTREGA}.csv ({len(sub)} predicciones)")
print(f"Distribucion: {', '.join(f'clase {k}: {v:.1%}' for k, v in dist.items())}")
# Out:
# Guardado: submissions/submission_ensamble_2red_1xgb_1rf_1nb_llm_v8_2.csv (8500 predicciones)
# Distribucion: clase 0: 41.2%, clase 1: 22.1%, clase 2: 36.7%
